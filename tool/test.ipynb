# %%
import pandas as pd

# %%
harm_c = pd.read_json('/home/sujin/psj2003/meme_detection/dataset/annotation/harm_c/harmc_annotations.jsonl', lines=True).reset_index(drop=True)
face = pd.read_json('/home/sujin/psj2003/meme_detection/dataset/source/facebook_img+text/txt/all.jsonl', lines=True).reset_index(drop=True)
memotion = pd.read_json('/home/sujin/psj2003/meme_detection/dataset/source/memotion_img+text/txt/all.jsonl', lines=True).reset_index(drop=True)
harm_p = pd.read_json('/home/sujin/psj2003/meme_detection/dataset/source/political_img+text/txt/all.jsonl', lines=True).reset_index(drop=True)

# %%
harm_c['raw_label'].count()
# Out:
# np.int64(3544)

# %%
face['labels'].count()
# Out:
# np.int64(9000)

# %%
memotion['labels'].count()
# Out:
# np.int64(6987)

# %%
harm_p['labels'].count()
# Out:
# np.int64(3469)
